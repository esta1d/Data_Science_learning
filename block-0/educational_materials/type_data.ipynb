# %% [markdown]
# # **Погружение в типы данных**

# %% [markdown]
# ***

# %% [markdown]
# ## Основные понятия модуля

# %% [markdown]
# ***`Python`*** — это высокоуровневый интерпретируемый кроссплатформенный
# язык программирования.
#
# ***`Алгоритм`*** — набор последовательных действий, направленных на
# достижение поставленной цели или решение конкретной задачи.
#
# ***`Функция`*** — фрагмент кода, к которому можно обратиться из любого другого
# места.
#
# ***`Переменная`*** — именованная область памяти компьютера, адрес которой
# позволяет получить доступ к данным.
#
# ***`Аргументы`*** — данные, которые необходимы функции для её работы.

# %% [markdown]
# ***

# %% [markdown]
# ## Типы данных

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ***

# %% [markdown]
# ### **`Список`**

# %% [markdown]
# #### Создание списка

# %%
a = []
a = list()
a = [1,2,3]
a = ["h", "hello", "world", "a"]
a = range(0,10)
a = range(0,10, 2)
a = range(10)
list1 = ["hello", 4, 3.5, (1,2), [1,2,3], {"name": "Bob", "age": 33}]

# %% [markdown]
# #### Индексы и срезы

# %% [markdown]
# ***`Срезом`*** называется подмножество элементов заданного порядка с возможным указанием шага.

# %%
a = ["a", "b", "c", "d", "e"]
a[:2] 
# получим элементы ["a", "b"]
a[2:4] 
# получим элементы ["c", "d"]
a[0:4:2] 
# возьмём только элементы на чётных индексах (0, 2)
# Out:
# ['a', 'c']

# %% [markdown]
# Часто можно «развернуть» список, сделав срез с шагом, равным -1.

# %%
a = ["a", "b", "c", "d", "e"]
b = a[::-1] 
# начать срез с первого элемента до последнего с шагом, равным -1

# %% [markdown]
# #### Работа со списком

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ***

# %% [markdown]
# ### **`Кортеж`**

# %% [markdown]
# #### Создание кортежа

# %%
tpl1 = ()
tpl1 = tuple()
tpl1 = (1,2,3)
tpl1 = (1,)
tpl1 = ("hello", 4, 3.5, (1,2), [1,2,3], {"name": "Bob", "age": 33})

# %% [markdown]
# Отличия от списка
#
# ***`Кортежи`*** — неизменяемые братья для списков. Можно использовать в ключах
# для словаря.

# %% [markdown]
# ***

# %% [markdown]
# ### **`Словарь`**

# %% [markdown]
# #### Создание словаря

# %%
dict1 = dict()
dict1 = {}
dict1 = {"name": "Bob", (1,2): 3, 3.5: [1,2,3]}

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Важно!**
#
# Поиск всегда идёт по ключу. Нельзя использовать значение в качестве ключа.
#
# Ключи в словаре должны быть уникальными. Если вы вставляете в словарь два одинаковых ключа с разными значениями, то тогда в качестве значения примется последнее значение, которое вы записали для ключа:

# %% [markdown]
# ***

# %% [markdown]
# ### **`Множество`**

# %% [markdown]
# ***`Множество`*** — это структура данных, состоящая из уникальных элементов (элементы не могут повторяться). Элементы внутри множества могут быть объектами неизменяемых типов (числа, строки и кортежи). Множества не поддерживают хранение изменяемых типов данных, таких как списки, словари и сами множества. Порядок элементов во множестве не фиксирован, то есть элементы не упорядочены.
#
# С множествами можно делать многие операции из теории множеств: объединение, пересечение, вычитание и т. д. Можно проверять принадлежность элемента к множеству.

# %% [markdown]
# #### Создание множества

# %%
set1 = set()
set1 = set([1,2,2,2,2,1])
set1 = {33}
set1 = {33, 22, 33, 1}
set1 = {33, 2.3, "hello", (1,2,3)}

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ***

# %% [markdown]
# ## Преобразование типов

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Операции с целыми и вещественными числами

# %% [markdown]
# ![image.png](attachment:image.png)
