# %%
import numpy as np 
import pandas as pd 
import plotly.express as px

# %%
model_data = pd.read_csv('data/model.csv')
model_data
# Out:
#          Month  Year      Waist       Hips     Height      Weight        BMI  \
# 0     December  1953  24.000000  36.000000  65.000000  118.000000  19.630000
# 1      January  1954  23.433172  34.698708  66.057258  114.936066  18.232168
# 2     February  1954  23.433172  34.698708  66.057258  114.936066  18.232168
# 3        March  1954  24.000000  35.000000  66.000000  118.000000  19.040000
# 4        April  1954  23.433172  34.698708  66.057258  114.936066  18.232168
# ..         ...   ...        ...        ...        ...         ...        ...
# 657  September  2008  25.000000  36.000000  67.000000  115.000000  18.010000
# 658    October  2008  24.000000  34.000000  65.000000  115.000000  19.130000
# 659   November  2008  21.000000  32.000000  66.000000  108.000000  17.430000
# 660   December  2008  25.000000  35.000000  68.000000  115.000000  17.480000
# 661    January  2009  23.500000  36.000000  67.000000  121.000000  18.950000
#
#      Waist/Hip
# 0     0.670000
# ...

# %% [markdown]
# ### Задание 7.2
#
# Рассчитайте среднее значение признаков  weight и height. Ответ округлите до сотых.

# %%
print('Среднее значение для признака Weight состовляет:',round(model_data['Weight'].mean(), 2),', а для признака Height:',round(model_data['Height'].mean(), 2))
# Out:
# Среднее значение для признака Weight состовляет: 114.94 , а для признака Height: 66.06

# %% [markdown]
# ### Задание 7.3
#
# Постройте матрицы визуализации корреляций, диаграммы рассеивания, проанализируйте и выполните задание.

# %%
# С увеличением обхвата бедер модели ИМТ незначительно _________
fig = px.scatter(model_data, x='BMI', y='Hips')
fig.show()

# %% [markdown]
# По графику видно, что чем больше обхват бедер, тем выше индекс масы тела

# %%
# Обхват бёдер имеет _________ связь с весом модели.
fig = px.scatter(model_data, y='Weight', x='Hips')
fig.show()

# %% [markdown]
# Чем выше обхват бедер, тем выше вес. Тут прямая связь.

# %%
# С увеличением обхвата бёдер _________ вес модели.
fig = px.scatter(model_data, y='Height', x='Hips')
fig.show()

# %% [markdown]
# Чем выше обхват бедер, тем выше вес. Тут прямая связь.

# %%
# Год выпуска журнала и вес модели имеют __________ связь. 
fig = px.scatter(model_data, x='Year', y='Weight')
fig.show()
